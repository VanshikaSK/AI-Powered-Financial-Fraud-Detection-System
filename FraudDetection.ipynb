# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("AIML Dataset.csv")

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            str
#  2   amount          float64
#  3   nameOrig        str
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        str
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), str(3)
# memory usage: 706.2 MB

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
df['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df["isFlaggedFraud"].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df.shape
# Out:
# (6362620, 11)

# %%
#Percentage of fraund to the total data
round((df['isFraud'].value_counts()[1]/df.shape[0])*100,2)
# Out:
# np.float64(0.13)

# %%
df['type'].value_counts().plot(kind='bar',title='Transaction',color='skyblue')
plt.xlabel('Transaction Type')
plt.ylabel('Count')
plt.show()

# %%
#Fraud rate by Types
fraud_by_type=df.groupby('type')['isFraud'].mean().sort_values(ascending=False)
fraud_by_type.plot(kind='bar',title="Fraud rate by Type",color="green")
plt.xlabel('Transaction Type')
plt.ylabel('Fraud Rate')
plt.show()

# %%
df['amount'].describe().astype(int)
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int64

# %%
sns.histplot(df['amount'],bins=100,color='salmon',log_scale=True)
plt.title('Transaction Amount Distribution (Log Scale)')
plt.xlabel('Amount')
plt.show()

# %%
#Relationship between isFraud and amount
sns.boxplot(data=df[df['amount']<50000],x='isFraud',y='amount')
plt.title('IsFraud vs Amount')
plt.xlabel('IsFraud')
plt.ylabel('Amount')
plt.show()

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
#balance chain and Anamolies
df['balance_diffOrg']=df['oldbalanceOrg']-df['newbalanceOrig']
df['balance_diffDest']=df['oldbalanceDest']-df["newbalanceDest"]

# %%
(df['balance_diffOrg']<0).sum()
# Out:
# np.int64(1399253)

# %%
(df['balance_diffDest']<0).sum()
# Out:
# np.int64(2806464)

# %%
df.head(4)
# Out:
#    step      type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT  9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT  1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER   181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT   181.00   C840083671          181.0            0.00
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
#
#    balance_diffOrg  balance_diffDest
# 0          9839.64               0.0
# 1          1864.28               0.0
# 2           181.00               0.0
# 3           181.00           21182.0

# %%
#fraud per step
fraud_per_step=df[df['isFraud']==1]["step"].value_counts().sort_index()
plt.plot(fraud_per_step.index,fraud_per_step.values,color="red")
plt.title('Fraud per step')
plt.xlabel('step (Time)')
plt.ylabel('Number of Fraud')
plt.show()

# %%
df.drop(columns="step",inplace=True)

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balance_diffOrg  balance_diffDest
# 0          9839.64               0.0
# 1          1864.28               0.0
# ...

# %%
#Customer which makes the highest amount of transaction like top sender and tob receiver
top_sender=df["nameOrig"].value_counts()
top_sender
# Out:
# nameOrig
# C2098525306    3
# C400299098     3
# C1999539787    3
# C1065307291    3
# C545315117     3
#               ..
# C786484425     1
# C1529008245    1
# C1162922333    1
# C1685995037    1
# C1280323807    1
# Name: count, Length: 6353307, dtype: int64

# %%
top_receiver=df["nameDest"].value_counts()
top_receiver
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
#               ...
# C1812552860      1
# C1470998563      1
# C1850423904      1
# C1881841831      1
# C2080388513      1
# Name: count, Length: 2722362, dtype: int64

# %%
fraud_user=df[df["isFraud"]==1]['nameOrig'].value_counts()
fraud_user
# Out:
# nameOrig
# C1305486145    1
# C840083671     1
# C1420196421    1
# C2101527076    1
# C137533655     1
#               ..
# C786484425     1
# C1529008245    1
# C1162922333    1
# C1685995037    1
# C1280323807    1
# Name: count, Length: 8213, dtype: int64

# %%
fraud_type=df[df["type"].isin(['TRANSFER','CASH_OUT'])]

# %%
fraud_type["type"].value_counts()
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
sns.countplot(data=fraud_type,x="type",hue="isFraud")
plt.title('Fraud Distribution in Transfer & Cash_Out')
plt.xlabel('Transaction Type')
plt.ylabel('Count')
plt.show()

# %%
df.columns
# Out:
# Index(['type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'balance_diffOrg', 'balance_diffDest'],
#       dtype='str')

# %%
#Correlation matrix
corr=df[["amount",'oldbalanceOrg', 'newbalanceOrig','oldbalanceDest', 'newbalanceDest', 'isFraud']].corr()
sns.heatmap(corr,annot=True,cmap="viridis")
plt.title('Correlation Matrix')
plt.show()

# %%
balance_zero_after_transfer=df[
    (df["oldbalanceOrg"]>0)&
     (df['newbalanceOrig']==0)&
      (df['type'].isin(['TRANSFER','CASH_OUT']))
]

# %%
balance_zero_after_transfer
# Out:
#              type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2        TRANSFER      181.00  C1305486145         181.00             0.0
# 3        CASH_OUT      181.00   C840083671         181.00             0.0
# 15       CASH_OUT   229133.94   C905080434       15325.00             0.0
# 19       TRANSFER   215310.30  C1670993182         705.00             0.0
# 24       TRANSFER   311685.89  C1984094095       10835.00             0.0
# ...           ...         ...          ...            ...             ...
# 6362615  CASH_OUT   339682.13   C786484425      339682.13             0.0
# 6362616  TRANSFER  6311409.28  C1529008245     6311409.28             0.0
# 6362617  CASH_OUT  6311409.28  C1162922333     6311409.28             0.0
# 6362618  TRANSFER   850002.52  C1685995037      850002.52             0.0
# 6362619  CASH_OUT   850002.52  C1280323807      850002.52             0.0
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# ...

# %%
len(balance_zero_after_transfer)
# Out:
# 1188074

# %%
df['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balance_diffOrg  balance_diffDest
# 0          9839.64               0.0
# 1          1864.28               0.0
# ...

# %%
df_model=df.drop(['nameOrig','nameDest','isFlaggedFraud'],axis=1)

# %%
df_model.head()
# Out:
#        type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2  TRANSFER    181.00          181.0            0.00             0.0
# 3  CASH_OUT    181.00          181.0            0.00         21182.0
# 4   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud  balance_diffOrg  balance_diffDest
# 0             0.0        0          9839.64               0.0
# 1             0.0        0          1864.28               0.0
# 2             0.0        1           181.00               0.0
# 3             0.0        1           181.00           21182.0
# 4             0.0        0         11668.14               0.0

# %%
categorical=['type']
numerical=['amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest']

# %%
y=df_model['isFraud']
X=df_model.drop('isFraud',axis=1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
preprocessor=ColumnTransformer(
    transformers= [
        ('num',StandardScaler(),numerical),
        ('cat',OneHotEncoder(drop="first"),categorical)
    ],
    remainder='drop'
)

# %%
pipeline=Pipeline([
    ('prep',preprocessor),
    ('clf',LogisticRegression(class_weight='balanced',max_iter=1000))
])

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred=pipeline.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97   1906351
#            1       0.02      0.93      0.04      2435
#
#     accuracy                           0.95   1908786
#    macro avg       0.51      0.94      0.51   1908786
# weighted avg       1.00      0.95      0.97   1908786

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1802592,  103759],
#        [    169,    2266]])

# %%
pipeline.score(X_test,y_test)*100
# Out:
# 94.55528278183097

# %%
import joblib
joblib.dump(pipeline,"fraud_detection_pipeline.pkl")
# Out:
# ['fraud_detection_pipeline.pkl']
